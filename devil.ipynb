# %% [markdown]
# # Pipeline Setup

# %%
# %%capture
# Clone from the official repository to get all the latest fixes
# !git clone 'https://github.com/clovaai/PointWSSIS.git'
# %cd /kaggle/working/PointWSSIS

# Fix NumPy compatibility FIRST (before installing other packages)
# !pip install "numpy<2.0.0" --force-reinstall --no-deps

# Then install other requirements
# !pip install -r requirements.txt

# %%
# !nvcc --version  # Shows CUDA 12.5
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Jun__6_02:18:23_PDT_2024
# Cuda compilation tools, release 12.5, V12.5.82
# Build cuda_12.5.r12.5/compiler.34385749_0

# %%
# %%capture
# %cd /kaggle/working/PointWSSIS/detectron2
# !python -m pip install -e .

# %%
# %%capture
# %cd /kaggle/working/PointWSSIS/AdelaiDet
# !rm -rf build/
# !python setup.py build develop

# %%
# %cd /kaggle/working/PointWSSIS
# !python -c "from detectron2 import _C; from adet import _C; print('✓ Extensions built')"
# Out:
# /kaggle/working/PointWSSIS
# /kaggle/working/PointWSSIS/AdelaiDet/adet/modeling/MEInst/MaskEncoding.py:9: FutureWarning: Decorating classes is deprecated and will be disabled in future versions. You should only decorate functions or methods. To preserve the current behavior of class decoration, you can directly decorate the `__init__` method and nothing else.
#   @torch.no_grad()
# ✓ Extensions built

# %% [markdown]
# # Dataset & Environment Preparation

# %%
# Create proper directory structure
# !mkdir -p /kaggle/working/coco
# !ln -s /kaggle/input/coco-2017-dataset/coco/train2017 /kaggle/working/coco/train2017
# !ln -s /kaggle/input/coco-2017-dataset/coco/val2017 /kaggle/working/coco/val2017

# Download annotations to writable location
# %cd /kaggle/working/PointWSSIS
# !python scripts/download_annotations.py all --output-dir /kaggle/working/coco/annotations

# Set environment variable WITHOUT quotes (this is critical!)
# %env DETECTRON2_DATASETS=/kaggle/working/coco
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/rapidfuzz-3.14.3-py3.11-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/Polygon3-3.0.9.1-py3.11-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 110.4 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ...
#
# Download Configuration:
# ...

# %% [markdown]
# ## ⚠️ Important Notes:
# 1. **NumPy**: Must be < 2.0 for binary compatibility
# 2. **Environment Variable**: NO QUOTES around the path
# 3. **Directory Structure**: Symlinks allow read-only input + writable annotations
# 4. **Repository**: Using clovaai/PointWSSIS for latest fixes (rapidfuzz, numpy, path handling)

# %%
# Verify the setup
# !python scripts/verify_setup.py

# Check that environment variable is set correctly (should NOT have quotes)
# !echo "DETECTRON2_DATASETS = $DETECTRON2_DATASETS"

# Verify annotations are downloaded
# !ls -lh /kaggle/working/coco/annotations/ | head -10

# %% [markdown]
# # Run

# %%
# %cd /kaggle/working/PointWSSIS/scripts
# Out:
# /kaggle/working/PointWSSIS/scripts

# %%
# !bash coco_1p.sh
# Out:
# Traceback (most recent call last):
#   File "/kaggle/working/PointWSSIS/AdelaiDet/tools/train_net.py", line 44, in <module>
#     from adet.evaluation import TextEvaluator
#   File "/kaggle/working/PointWSSIS/AdelaiDet/adet/evaluation/__init__.py", line 1, in <module>
#     from .text_evaluation_all import TextEvaluator
#   File "/kaggle/working/PointWSSIS/AdelaiDet/adet/evaluation/text_evaluation_all.py", line 23, in <module>
#     from adet.evaluation import text_eval_script_ic15
#   File "/kaggle/working/PointWSSIS/AdelaiDet/adet/evaluation/text_eval_script_ic15.py", line 11, in <module>
#     from rapidfuzz import string_metric
# ImportError: cannot import name 'string_metric' from 'rapidfuzz' (/usr/local/lib/python3.11/dist-packages/rapidfuzz-3.14.3-py3.11-linux-x86_64.egg/rapidfuzz/__init__.py)
# Traceback (most recent call last):
#   File "/kaggle/working/PointWSSIS/AdelaiDet/tools/train_net.py", line 44, in <module>
#     from adet.evaluation import TextEvaluator
# ...
